# %% [markdown]
# # 1. Train

# %%
python tools/train.py --batch 32 --conf configs/yolov6s.py --data data/dataset.yaml --epochs 500 --device 0 --workers 1
# Out:
# ^C

# %% [markdown]
# # 2. Inference

# %%
# !python tools/infer.py --weights 'runs/train/exp/weights/best_ckpt.pt' --source 'data/fire_dataset/fire_images' --project 'data/fire_dataset/yolov6results' --yaml 'data/dataset.yaml' --save-img --device 0
# Out:
# Namespace(agnostic_nms=False, classes=None, conf_thres=0.25, device='0', half=False, hide_conf=False, hide_labels=False, img_size=640, iou_thres=0.45, max_det=1000, name='exp', project='data/fire_dataset/yolov6results', save_img=False, save_txt=False, source='data/fire_dataset/fire_images', weights='runs/train/exp/weights/best_ckpt.pt', yaml='data/dataset.yaml')
# Save directory already existed
# Loading checkpoint from runs/train/exp/weights/best_ckpt.pt
#
# Fusing model...
#   0% 0/419 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 100% 419/419 [03:31<00:00,  1.98it/s]

# %%
# !python tools/infer.py --weights 'runs/train/exp/weights/best_ckpt.pt' --source 'data/fire_dataset/non_fire_images' --project 'data/fire_dataset/yolov6results' --yaml 'data/dataset.yaml' --save-img --device 0
# Out:
# Namespace(agnostic_nms=False, classes=None, conf_thres=0.25, device='0', half=False, hide_conf=False, hide_labels=False, img_size=640, iou_thres=0.45, max_det=1000, name='exp', project='data/fire_dataset/yolov6results', save_img=False, save_txt=False, source='data/fire_dataset/non_fire_images', weights='runs/train/exp/weights/best_ckpt.pt', yaml='data/dataset.yaml')
# Save directory already existed
# Loading checkpoint from runs/train/exp/weights/best_ckpt.pt
#
# Fusing model...
#   0% 0/244 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#  41% 99/244 [00:52<01:16,  1.88it/s]
# Traceback (most recent call last):
# ...
